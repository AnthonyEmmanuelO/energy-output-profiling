# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('result.csv')

# %%
df.describe()
# Out:
#        Solar Irradiance    PV Current    PV Voltage    PV Energy  \
# count      29088.000000  29088.000000  29088.000000  29088.00000
# mean         471.142883     52.274813    114.120035    136.31996
# std          327.936975      5.755070     52.819076    266.84049
# min          100.725000      0.000000      0.000000      0.00000
# 25%          221.515492     49.342000     90.460000      0.00000
# 50%          305.687031     49.476000     90.702000      0.00000
# 75%          691.844540     58.650000    121.106500    100.00000
# max         1499.486500     61.800000    554.500000   1400.00000
#
#        clusters_pred
# count   29088.000000
# mean        0.824876
# std         1.277039
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         5.000000

# %%
status_1=df.loc[df['clusters_pred'] == 0]
status_2=df.loc[df['clusters_pred'] == 1]
status_3=df.loc[df['clusters_pred'] == 2]
status_4=df.loc[df['clusters_pred'] == 3]
status_5=df.loc[df['clusters_pred'] == 4]
status_6=df.loc[df['clusters_pred'] == 5]

# %%
fig = plt.figure(figsize=(16,10))

ax1 = fig.add_subplot(3, 2, 1)
status_1.plot.scatter(x = "PV Voltage", y = "PV Current", ax=ax1)

ax2 = fig.add_subplot(3, 2, 2)
status_2.plot.scatter(x = "PV Voltage", y = "PV Current", ax=ax2)

ax3 = fig.add_subplot(3, 2, 3)
status_3.plot.scatter(x = "PV Voltage", y = "PV Current", ax=ax3)

ax4 = fig.add_subplot(3, 2, 4)
status_4.plot.scatter(x = "PV Voltage", y = "PV Current", ax=ax4)

ax5 = fig.add_subplot(3, 2, 5)
status_5.plot.scatter(x = "PV Voltage", y = "PV Current", ax=ax5)

ax6 = fig.add_subplot(3, 2, 6)
status_6.plot.scatter(x = "PV Voltage", y = "PV Current", ax=ax6)

# %%
fig = plt.figure(figsize=(16,10))

ax1 = fig.add_subplot(3, 2, 1)
status_1.plot.scatter(x = "Solar Irradiance", y = "PV Energy", ax=ax1)

ax2 = fig.add_subplot(3, 2, 2)
status_2.plot.scatter(x = "Solar Irradiance", y = "PV Energy", ax=ax2)

ax3 = fig.add_subplot(3, 2, 3)
status_3.plot.scatter(x = "Solar Irradiance", y = "PV Energy", ax=ax3)

ax4 = fig.add_subplot(3, 2, 4)
status_4.plot.scatter(x = "Solar Irradiance", y = "PV Energy", ax=ax4)

ax5 = fig.add_subplot(3, 2, 5)
status_5.plot.scatter(x = "Solar Irradiance", y = "PV Energy", ax=ax5)

ax6 = fig.add_subplot(3, 2, 6)
status_6.plot.scatter(x = "Solar Irradiance", y = "PV Energy", ax=ax6)

# %%
"""
Analysis:

Status 1: Early in the morning (dusk). Increasing Current, voltage unstable (fluctuating). No energy harvested
Status 2: 9-11 am. Current from 60 to 62 A, Voltage converging at 100 to 300 V
Status 3: Decreased Voltage,afternoon
Status 4: Late afternoon nearing night time, decreasing voltage, decreasing current
Status 5:Peak sunlight hours, high noon 
Status 6: maximum voltage, constant current


"""
# Out:
# '\nAnalysis:\n\nStatus 1: Early in the morning (dusk). Increasing Current, voltage unstable (fluctuating). No energy harvested\nStatus 2: 9-11 am. Current from 60 to 62 A, Voltage converging at 100 to 300 V\nStatus 3: Decreased Voltage,afternoon\nStatus 4: Late afternoon nearing night time, decreasing voltage, decreasing current\nStatus 5:Peak sunlight hours, high noon \nStatus 6: maximum voltage, constant current\n\n\n'
